# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

#packages for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Import for Linear Regression
import sklearn
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#    Responden  Jumlah_Produksi  Luas_Lahan  Jumlah_Pohon  Pupuk_Kandang  \
# 0          1              200         900            20             50
# 1          2              500         500            50            250
# 2          3              500         500            50            250
# 3          4              900         900            60            450
# 4          5              900         900            60            450
#
#    Pupuk_Phonska  Pestisida  Tenaga_Kerja
# 0             10        600            27
# 1             25       1600            21
# 2             25       1600            33
# 3             45       3600            40
# 4             45       3600            50

# %%
# Import for Linear Regression
lreg = LinearRegression()

# %%
# Data Columns
X_multi = df.drop('Jumlah_Produksi',1)

# Targets
Y_target = df.Jumlah_Produksi
# Out:
# <ipython-input-27-1b3235cf137c>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X_multi = df.drop('Jumlah_Produksi',1)

# %%
lreg.fit(X_multi,Y_target)
# Out:
# LinearRegression()

# %%
print(' The estimated intercept coefficient is %.2f ' %lreg.intercept_)
# Out:
#  The estimated intercept coefficient is 14.64

# %%
print(' The number of coefficients used was %d ' % len(lreg.coef_))
# Out:
#  The number of coefficients used was 7

# %%
# Set a DataFrame from the Features
coeff_df = DataFrame(df.columns)
coeff_df.columns = ['Features']

# Set a new column lining up the coefficients from the linear regression
coeff_df["Coefficient Estimate"] = pd.Series(lreg.coef_)

# Show
coeff_df
# Out:
#           Features  Coefficient Estimate
# 0        Responden             -0.169322
# 1  Jumlah_Produksi             -0.003352
# 2       Luas_Lahan              1.575422
# 3     Jumlah_Pohon              0.611646
# 4    Pupuk_Kandang              4.599807
# 5    Pupuk_Phonska              0.079762
# 6        Pestisida              0.318905
# 7     Tenaga_Kerja                   NaN
